# %%
# Master Time Series table script

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_1 = pd.read_csv('time_series_19-covid-Confirmed.csv')
df_2 = pd.read_csv('time_series_19-covid-Deaths.csv')
df_3 = pd.read_csv('time_series_19-covid-Recovered.csv')

# %%
#dfs = ['df_1', 'df_2', 'df_3']
countries = ['Spain', 'Italy']

# %%
df_1a = df_1[df_1['Country/Region'].isin(countries)] 
df_2a = df_2[df_2['Country/Region'].isin(countries)]
df_3a = df_3[df_3['Country/Region'].isin(countries)]

# %%
df_1a
# Out:
#    Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 16          Italy        0        0        0        0        0        0
# 18          Spain        0        0        0        0        0        0
#
#     1/28/20  1/29/20  1/30/20  ...  3/2/20  3/3/20  3/4/20  3/5/20  3/6/20  \
# 16        0        0        0  ...    2036    2502    3089    3858    4636
# 18        0        0        0  ...     120     165     222     259     400
#
#     3/7/20  3/8/20  3/9/20  3/10/20  3/11/20
# 16    5883    7375    9172    10149    12462
# 18     500     673    1073     1695     2277
#
# [2 rows x 51 columns]

# %%
df_1a.drop(['Province/State', 'Lat', 'Long'], axis=1, inplace=True)
df_2a.drop(['Province/State', 'Lat', 'Long'], axis=1, inplace=True)
df_3a.drop(['Province/State', 'Lat', 'Long'], axis=1, inplace=True)
# Out:
# /Users/tadeobarreiro/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
#for i in dfs:
df_1a['Status'] = 'Confirmed'
df_2a['Status'] = 'Dead'
df_3a['Status'] = 'Recovered'
# Out:
# /Users/tadeobarreiro/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/tadeobarreiro/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/tadeobarreiro/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df = df_1a.append(df_2a)
df = df.append(df_3a)

# %%
df
# Out:
#    Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 16          Italy        0        0        0        0        0        0
# 18          Spain        0        0        0        0        0        0
# 16          Italy        0        0        0        0        0        0
# 18          Spain        0        0        0        0        0        0
# 16          Italy        0        0        0        0        0        0
# 18          Spain        0        0        0        0        0        0
#
#     1/28/20  1/29/20  1/30/20  ...  3/3/20  3/4/20  3/5/20  3/6/20  3/7/20  \
# 16        0        0        0  ...    2502    3089    3858    4636    5883
# 18        0        0        0  ...     165     222     259     400     500
# 16        0        0        0  ...      79     107     148     197     233
# 18        0        0        0  ...       1       2       3       5      10
# 16        0        0        0  ...     160     276     414     523     589
# ...

# %%
df11 = pd.crosstab(df['Country/Region'], df['1/22/20'], df['1/23/20'])
df11
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-98-97e6035b855a> in <module>()
# ----> 1 df11 = pd.crosstab(df['Country/Region'], df['1/22/20'], df['1/23/20'])
#       2 df11
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/pivot.py in crosstab(index, columns, values, rownames, colnames, aggfunc, margins, margins_name, dropna, normalize)
#     506
#     507     if values is not None and aggfunc is None:
# --> 508         raise ValueError("values cannot be used without an aggfunc.")
#     509
#     510     from pandas import DataFrame
#
# ValueError: values cannot be used without an aggfunc.

# %%
#df1 = df.stack()
#df1

# %%
df_1_2 = df_1.transpose()
df_1_2
# Out:
#                      0      1          2        3         4    \
# Province/State       NaN    NaN        NaN      NaN       NaN
# Country/Region  Thailand  Japan  Singapore    Nepal  Malaysia
# Lat                   15     36     1.2833  28.1667       2.5
# Long                 101    138    103.833    84.25     112.5
# 1/22/20                2      2          0        0         0
# 1/23/20                3      1          1        0         0
# 1/24/20                5      2          3        0         0
# 1/25/20                7      2          3        1         3
# 1/26/20                8      4          4        1         4
# 1/27/20                8      4          5        1         4
# 1/28/20               14      7          7        1         4
# 1/29/20               14      7          7        1         7
# 1/30/20               14     11         10        1         8
# 1/31/20               19     15         13        1         8
# ...

# %%
df.to_csv('time_series_19-covid_Merged.csv')
